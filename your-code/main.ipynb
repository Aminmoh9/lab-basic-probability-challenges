# %% [markdown]
# # Lab | Basic Probability - Challenges
#
# ## Challenge 1
#
# A and B are events of a probability space with $(\omega, \sigma, P)$ such that $P(A) = 0.3$, $P(B) = 0.6$ and $P(A \cap B) = 0.1$
#
# Which of the following statements are false?
# * $P(A \cup B) = 0.6$
# * $P(A \cap B^{C}) = 0.2$
# * $P(A \cap (B \cup B^{C})) = 0.4$
# * $P(A^{C} \cap B^{C}) = 0.3$
# * $P((A \cap B)^{C}) = 0.9$

# %% [markdown]
# #Wrong Statements:
# * $P(A \cup B) = 0.6$
# * $P(A \cap (B \cup B^{C})) = 0.4$
# * $P(A^{C} \cap B^{C}) = 0.3$

# %% [markdown]
# ## Challenge 2
# There is a box with 10 white balls, 12 red balls and 8 black balls. Calculate the probability of:
# * Taking a white ball out.
# * Taking a white ball out after taking a black ball out.
# * Taking a red ball out after taking a black and a red ball out.
# * Taking a red ball out after taking a black and a red ball out with reposition.
#
# **Hint**: Reposition means putting back the ball into the box after taking it out.

# %%
# Your code here
# total_balls_in_the_box = 10 (White) + 12 (Red) + 8 (Black) = 30

# Taking a white ball
p_white= round(10/30, 2)

#Taking a white ball after a black ball (without reposition)
#If a black ball was taken, 29 balls remain.

remaining_white_balls= 10

p_white_blackRemoved = round(10 / 29, 2)

#Taking a red ball after a black and red ball (without reposition):
#After removing black and red, 28 balls remain.

remaining_red_balls = 11

p_read_blackAndRedRemoved = round(11 / 28, 2)

#Taking a red ball after a black and red ball (with reposition):

#Since balls were replaced, probability remains as it was initially.

p_red = round(12 / 30, 2)

print(f'Probablity of taking a white ball= {p_white} %')
print(f'Probability of taking a white ball out after taking a black ball out = {p_white_blackRemoved} %')
print(f'Probability of taking a red ball out after taking a black and a red ball out = {p_read_blackAndRedRemoved} %')
print(f'Probability of taking a red ball out after taking a black and a red ball out with reposition = {p_red} %')
# Out:
# Probablity of taking a white ball= 0.33 %
# Probability of taking a white ball out after taking a black ball out = 0.34 %
# Probability of taking a red ball out after taking a black and a red ball out = 0.39 %
# Probability of taking a red ball out after taking a black and a red ball out with reposition = 0.4 %

# %% [markdown]
# ## Challenge 3
#
# You are planning to go on a picnic today but the morning is cloudy. You hate rain so you don't know whether to go out or stay home! To help you make a decision, you gather the following data about rainy days:
#
# * 50% of all rainy days start off cloudy!
# * Cloudy mornings are common. About 40% of days start cloudy.
# * This month is usually dry so only 3 of 30 days (10%) tend to be rainy.
#
# What is the chance of rain during the day?

# %%
# Your code here
# P(Cloudy ∣ Rain)= 0.5
# P(Cloudy)= 0.4
# P(Rain) = 0.1

# P(Rain|Cloudy) = P(Cloudy|Rain) * P(Rain) / P(Cloudy)

# Will insert the values 

p_rain_cloudy = 0.5* 0.1 / 0.4

print(f'The chance of rain during the day is {p_rain_cloudy} %')
# Out:
# The chance of rain during the day is 0.125 %

# %% [markdown]
# ## Challenge 4
#
#
#  * If someone flies to China, the probability of getting Covid is 1%
#  * If someone flies to Italy, the probability of getting Covid is 20%
#
# I roll 1 dice with numbers 1, 2, 3, 4, 5, 6:
#  * If 1: I fly to Italy
#  * If not 1: I fly to China
#
# During my trip, I got Covid. What is the probability that I flew to China?

# %%
# Your code here

# Probability of rolling 1 (Italy) = 1/6 = 
# Probability of rolling 2,3,4,5,6 (China) = 5/6 

# P(Covid ∣ Italy) = 0.2
# P(Covid ∣ China) = 0.01


# P(China ∣ Covid) = P(Covid ∣ China) *  P(China) / P(Covid)

# We calculate first the P(Covid)
# P(Covid) =  (0.2 * (1/6)) +(0.01 *5/6) 
p_covid= (0.2 * (1/6)) +(0.01 *(5/6)) 

# Now we find P(China ∣ Covid)

p_china_covid = 0.01 * (5/6) / p_covid

print(f'The probability that I flew to China is {p_china_covid} %')
# Out:
# The probability that I flew to China is 0.2 %

# %% [markdown]
# ## BONUS
#
# You roll 2 dice. What is the probability that the sum of the numbers is 7? And 8? And 9? Then simulate 10000 times and draw a countplot.

# %% [markdown]
# your explanation here

# %%
# Your code here

# Total outcome in rolling two dice = 6 * 6 = 36

# Possible ways to get a sum of 7 (from two dice)
# (1,6),(2,5),(3,4),(4,3),(5,2),(6,1) → 6 way= 6/ 36

# Possibe ways to get a sum of 8 (from two dice)
# (2,6),(3,5),(4,4),(5,3),(6,2) → 5 ways = 5/36

# Possibe ways to get a sum of 8 (from two dice)
# (3,6),(4,5),(6,3),(5,4) → 4 ways = 4/36



# P(Sum = 7 or 8 or 9) = (6+5+4) / 36 = 15/36 

p_sum_7_or_8_or_9 = 15/36

p_sum_7 = 6/36
p_sum_8 = 5/36
p_sum_9 = 4/36
print(f' The probability of that sum of the numbers is 7 or 8 or 9 from rolling two dice is {p_sum_7_or_8_or_9} %')

print(f' The probability of that sum of the numbers is 7 is {p_sum_7} %')

print(f' The probability of that sum of the numbers is 8 is from rolling two dice is {p_sum_8} %')

print(f' The probability of that sum of the numbers is 9 is from rolling two dice is {p_sum_9} %')
# Out:
#  The probability of that sum of the numbers is 7 or 8 or 9 from rolling two dice is 0.4166666666666667 %
#  The probability of that sum of the numbers is 7 is 0.16666666666666666 %
#  The probability of that sum of the numbers is 8 is from rolling two dice is 0.1388888888888889 %
#  The probability of that sum of the numbers is 9 is from rolling two dice is 0.1111111111111111 %

# %%
# To simulate the 10000 times

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

simulations = 10000

results = [np.random.randint(1, 7) + np.random.randint(1, 7) for _ in range(simulations)]

plt.figure(figsize=(10, 5))
sns.countplot(x=results, hue= results, palette="viridis", legend=False)
plt.title("Countplot of Dice Roll Sums (10,000 simulations)")
plt.xlabel("Sum of Two Dice")
plt.ylabel("Frequency")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# ## Bonus
#
# One thousand people were asked through a telephone survey whether they thought more street lighting is needed at night or not.
#
# Out of the 480 men that answered the survey, 324 said yes and 156 said no. On the other hand, out of the 520 women that answered, 351 said yes and 169 said no.
#
# We wonder if men and women have a different opinions about the street lighting matter. Is gender relevant or irrelevant to the question?
#
# Consider the following events:
# - The answer is yes, so the person that answered thinks that more street lighting is needed.
# - The person who answered is a man.
#
# We want to know if these events are independent, that is, if the fact of wanting more light depends on whether one is male or female. Are these events independent or not?
#
# **Hint**: To clearly compare the answers by gender, it is best to place the data in a table.

# %% [markdown]
# | Gender  | Yes  | No |  |
# |---|---|---|---|
# | Men  | 0.324  | 0.156 | 0.48 |
# | Women  | 0.351  | 0.169 | 0.52 |
# |   | 0.675  | 0.325 |

# %%
# Your code here

# We check independence by comparing

# P(Yes∣Male) = 324/480 = 0.675
# P(Yes∣Female) = 351/520 = 0.675

# P(Yes)= (324+351) / 1000 = 0.675

# Since P(Yes∣Male) = P(Yes∣Female) = P(Yes) , the event are independent. Gender does not affect whether someone thinks street ligghting is needed.
